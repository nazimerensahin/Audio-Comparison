# %%
# Gerekli kütüphanelerin içe aktarılması
import matplotlib.pyplot as plt
import numpy as np
import librosa
import librosa.display

# İşlenecek ses dosyalarının yolları
file_1 = "/Users/nazimerensahin/Desktop/1.wav"
file_2 = "/Users/nazimerensahin/Desktop/2.wav"

# İşlenecek ses dosyalarının isimlendirmeleri
label_1 = "Ses Dosyası 1"
label_2 = "Ses Dosyası 2"

# Ses dosyalarını yükle (waveform ve sample rate alınır)
wave_1, sr_1 = librosa.load(file_1, sr=None)
wave_2, sr_2 = librosa.load(file_2, sr=None)

# RMS hesaplaması için analiz pencere boyutu ve adım belirleme
frame_size = 2048
hop_length = 512

# RMS tabanlı envelope (zarf) hesaplama fonksiyonu
def compute_envelope(signal, frame_size, hop_length):
	rms = librosa.feature.rms(y=signal, 
frame_length=frame_size, hop_length=hop_length)[0]
	return rms

# Her iki sinyalin envelope bilgilerini hesapla
envelope_1 = compute_envelope(wave_1, frame_size, hop_length)
envelope_2 = compute_envelope(wave_2, frame_size, hop_length)

# Envelope değerlerine karşılık gelen zaman eksenlerini oluştur
time_1 = np.linspace(0, 
len(envelope_1) * hop_length / sr_1, num=len(envelope_1))
time_2 = np.linspace(0, 
len(envelope_2) * hop_length / sr_2, num=len(envelope_2))

# Grafik boyutunu ayarla
plt.figure(figsize=(12, 5))

# Zarf eğrilerini çiz
plt.plot(time_1, envelope_1, 
label=f"{label_1} Envelope", color='blue')
plt.plot(time_2, envelope_2, 
label=f"{label_2} Envelope", color='orange')

# Görsel ayarlamalar
plt.title("Attack & Release Davranış Karşılaştırması")
plt.xlabel("Zaman (Saniye)")
plt.ylabel("Envelope (RMS)")
plt.legend(loc="upper right")
plt.grid(True)
plt.tight_layout()
plt.show()
