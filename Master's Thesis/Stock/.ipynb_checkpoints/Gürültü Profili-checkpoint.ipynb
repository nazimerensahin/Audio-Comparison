# %%
import matplotlib.pyplot as plt # Grafik çizimleri için kullanılan kütüphane
import numpy as np # Sayısal hesaplamaları
import librosa # Ses yükleme ve analizi
import librosa.display # Ses dalga formu görselleştirme
from scipy import signal # Spektrogram ve sinyal işlemleri

# Ses dosyalarının yolları
file_1 = "/Users/nazimerensahin/Desktop/1.wav" # İlk karşılaştırılacak ses dosyasının yolu
file_2 = "/Users/nazimerensahin/Desktop/2.wav" # İkinci karşılaştırılacak ses dosyasının yolu

# Ses dosyalarının isimlendirmeleri
label_1 = "Ses Dosyası 1" # Grafik etiketi için ilk dosya ismi
label_2 = "Ses Dosyası 2" # Grafik etiketi için ikinci dosya ismi

# Ses dosyalarını yükleme
wave_1, sr_1 = librosa.load(file_1, sr=None) # Birinci ses dosyasını yükleme
wave_2, sr_2 = librosa.load(file_2, sr=None) # İkinci ses dosyasını yükleme

# Gürültü profili karşılaştırma fonksiyonu
def plot_noise_profile(signal_1, signal_2, sr, label_1, label_2):
    epsilon = 1e-10 # Logaritmik dönüşümde sıfıra bölmeyi engellemek için küçük sabit değer

    # Birinci ses dosyası için spektrogram ve ortalama güç hesaplama
    freqs_1, _, Sxx_1 = signal.spectrogram(signal_1, sr) # Spektrogram hesaplama
    power_1 = np.mean(10 * np.log10(Sxx_1 + epsilon), axis=1) # Ortalama güç (dB cinsinden)

    # İkinci ses dosyası için spektrogram ve ortalama güç hesaplama
    freqs_2, _, Sxx_2 = signal.spectrogram(signal_2, sr) # Spektrogram hesaplama
    power_2 = np.mean(10 * np.log10(Sxx_2 + epsilon), axis=1) # Ortalama güç (dB cinsinden)

    # Grafik çizimi
    plt.figure(figsize=(10, 5)) # Grafik boyutunu ayarlama (genişlik x yükseklik)
    plt.plot(freqs_1, power_1, label=label_1, linestyle="--", color="blue") # Birinci modelin gürültü gücünü çizme
    plt.plot(freqs_2, power_2, label=label_2, linestyle="-", color="red") # İkinci modelin gürültü gücünü çizme
    plt.title(f"Gürültü Profili Karşılaştırması: {label_1} vs {label_2}") # Grafik başlığı ayarlama
    plt.xlabel("Frekans (Hz)") # X ekseni etiketi
    plt.ylabel("Gürültü Gücü (dB)") # Y ekseni etiketi
    plt.xlim(0, 25000) # Frekans aralığını sınırlama (0-25 kHz)
    plt.legend() # Etiket kutusunu gösterme
    plt.grid(True) # Grafik ızgara çizgilerini aktif etme
    plt.tight_layout() # Grafik içeriğini sıkılaştırma
    plt.show() # Grafiği ekranda gösterme

# Fonksiyonu çağırarak analiz gerçekleştirme
plot_noise_profile(wave_1, wave_2, sr_1, label_1, label_2) # İki ses dosyasının gürültü profillerini karşılaştırma
