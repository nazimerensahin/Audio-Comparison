# %%
import matplotlib.pyplot as plt # Grafik çizimleri için kullanılan kütüphane
import numpy as np # Sayısal hesaplamalar
import librosa  # Ses yükleme ve analizi
import librosa.display  # Ses dalga formu görselleştirme

# Ses dosyalarının yolları
file_1 = "/Users/nazimerensahin/Desktop/processed/teletronix_white_noise.wav" # İlk karşılaştırılacak ses dosyasının yolu
file_2 = "/Users/nazimerensahin/Desktop/processed/urei_white_noise.wav" # İkinci karşılaştırılacak ses dosyasının yolu

# Ses dosyalarının isimlendirmeleri
label_1 = "Ses Dosyası 1" # Grafik etiketi için ilk dosya ismi
label_2 = "Ses Dosyası 2" # Grafik etiketi için ikinci dosya ismi

# THD (Total Harmonic Distortion) hesaplama fonksiyonu
def thd_analysis(signal, sr):
    ft = np.fft.fft(signal) # Ses sinyaline Fourier dönüşümü uygulayarak frekans bileşenlerini elde etme
    magnitude = np.abs(ft[:len(ft) // 2]) # Pozitif frekansların genlik spektrumunu çıkartma
    freq_bins = np.fft.fftfreq(len(signal), d=1/sr)[:len(ft)//2] # Pozitif frekans ekseni değerlerini hesaplama

    fundamental_idx = np.argmax(magnitude) # En yüksek genliğe sahip frekans bileşenini (temel frekans) bulma
    fundamental_freq = freq_bins[fundamental_idx] # Temel frekansın değerini alma

    harmonics_magnitude = 0 # Harmonik bileşenlerin toplam genliği için başlangıç değeri
    for n in range(2, 6): # 2. ila 5. harmonik bileşenleri dolaşma
        harmonic_freq = n * fundamental_freq # Her bir harmonik frekansı hesaplama
        harmonic_idx = np.argmin(np.abs(freq_bins - harmonic_freq)) # İlgili harmonik frekansın indeksini bulma
        harmonics_magnitude += magnitude[harmonic_idx] # İlgili harmonik genliği toplama

    thd = harmonics_magnitude / magnitude[fundamental_idx] # Toplam harmonik bozulmayı temel frekansa oranlayarak hesaplama
    return thd # Hesaplanan THD değerini döndürme

# Ses dosyalarını yükle ve analiz etme
signals = [librosa.load(file_1, sr=None), librosa.load(file_2, sr=None)] # Sinyal ve örnekleme oranlarını elde etme
thd_values = [thd_analysis(sig, sr) for sig, sr in signals] # Her bir ses dosyası için THD hesaplaması yapma

# THD değerlerini görselleştirme
plt.figure(figsize=(8, 5)) # Grafik boyutunu ayarlama
plt.bar([label_1, label_2], thd_values, color='mediumseagreen') # Bar grafik çizme ve her dosyanın THD değeri için bir sütun ekleme
plt.ylabel("THD Değeri") # Y ekseni etiketi olarak THD değerini gösterme
plt.title(f"{label_1} ve {label_2} Arasında THD Karşılaştırması") # Grafik başlığını ayarlama
plt.ylim(0, max(thd_values) * 1.2) # Y ekseni sınırlarını otomatik olarak maksimum değere göre ayarlama
plt.grid(axis='y', linestyle='--', alpha=0.7) # Y ekseni boyunca noktalı ızgara çizgilerini ekleme
plt.tight_layout() # Grafik öğeleri arasında boşlukları otomatik olarak düzenleme
plt.show() # Grafiği ekranda gösterme
