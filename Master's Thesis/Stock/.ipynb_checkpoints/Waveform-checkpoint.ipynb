# %%
# Kütüphaneler ve işleme araçları
import matplotlib.pyplot as plt 
import librosa
import librosa.display

# Ses dosyalarının yolları
file_1 = "/Users/nazimerensahin/Desktop/1.wav"
file_2 = "/Users/nazimerensahin/Desktop/2.wav"

# Ses dosyalarının isimlendirmeleri
label_1 = "Ses Dosyası 1"
label_2 = "Ses Dosyası 2"

# Ses dosyalarını yükleme
wave_1, sr_1 = librosa.load(file_1, sr=None)
wave_2, sr_2 = librosa.load(file_2, sr=None)

# Grafik çizimi
plt.figure(figsize=(12, 4))
librosa.display.waveshow(wave_1, sr=sr_1,
alpha=0.5, color='blue', label=label_1)
librosa.display.waveshow(wave_2, sr=sr_2, 
alpha=0.5, color='red', label=label_2)

# Başlık, eksenler ve diğer ayarlar
plt.title(f"{label_1} vs {label_2} - Waveform Karşılaştırması")
plt.xlabel("Zaman (saniye)")
plt.ylabel("Genlik") 
plt.ylim((-0.4, 0.4))
plt.legend(loc="upper right")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Kütüphaneler ve işleme araçları
import matplotlib.pyplot as plt 
import librosa
import librosa.display

# Ses dosyalarının yolları
file_1 = "/Users/nazimerensahin/Desktop/1.wav"
file_2 = "/Users/nazimerensahin/Desktop/2.wav"

# Ses dosyalarının isimlendirmeleri
label_1 = "Ses Dosyası 1"
label_2 = "Ses Dosyası 2"

# Ses dosyalarını yükleme
wave_1, sr_1 = librosa.load(file_1, sr=None)
wave_2, sr_2 = librosa.load(file_2, sr=None)

# Grafik çizimi
plt.figure(figsize=(12, 4))
librosa.display.waveshow(wave_1, sr=sr_1,
alpha=0.5, color='blue', label=label_1)
librosa.display.waveshow(wave_2, sr=sr_2, 
alpha=0.5, color='red', label=label_2)

# Başlık, eksenler ve diğer ayarlar
plt.title(f"{label_1} vs {label_2} - Waveform Karşılaştırması")
plt.xlabel("Zaman (saniye)")
plt.ylabel("Genlik") 
plt.ylim((-0.4, 0.4))
plt.legend(loc="upper right")
plt.grid(True)
plt.tight_layout()
plt.show()
