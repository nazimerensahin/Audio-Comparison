# %%
import matplotlib.pyplot as plt # Grafik çizimleri için kullanılan kütüphane
import numpy as np # Sayısal hesaplamaları
import librosa # Ses yükleme ve analizi
import librosa.display # Ses dalga formu görselleştirme

# Ses dosyalarının yolları
file_1 = "/Users/nazimerensahin/Desktop/processed/teletronix_white_noise.wav" # İlk karşılaştırılacak ses dosyasının yolu
file_2 = "/Users/nazimerensahin/Desktop/processed/urei_white_noise.wav" # İkinci karşılaştırılacak ses dosyasının yolu

# Ses dosyalarının isimlendirmeleri
label_1 = "Ses Dosyası 1" # Grafik etiketi için ilk dosya ismi
label_2 = "Ses Dosyası 2" # Grafik etiketi için ikinci dosya ismi

def calculate_snr(signal, sr):
    frame_length = int(sr * 0.05) # 50 ms'lik çerçeve uzunluğu
    hop_length = frame_length // 2 # Kayma uzunluğu
    rms_energy = librosa.feature.rms(y=signal, frame_length=frame_length, hop_length=hop_length)[0] # RMS enerji hesaplama
    threshold = np.percentile(rms_energy, 20) # En düşük %20 RMS enerji eşiği (gürültü kabul edilir)
    noise_indices = rms_energy < threshold # Gürültülü çerçeveleme

    frame_times = librosa.frames_to_time(np.arange(len(rms_energy)), sr=sr, hop_length=hop_length) # Çerçevelerin zaman karşılıkları
    noise_signal = np.zeros_like(signal) # Gürültü sinyali için boş dizi tanımı

    for i, frame_time in enumerate(frame_times): # Her çerçeveyi kontrol etme
        start_sample = librosa.time_to_samples(frame_time, sr=sr) # Başlangıç örneği
        end_sample = librosa.time_to_samples(frame_time + 0.05, sr=sr) # Bitiş örneği (50 ms sonrası)
        if noise_indices[i]:
            noise_signal[start_sample:end_sample] = signal[start_sample:end_sample] # Gürültü bölgesi kopyalanır

    signal_power = np.mean(signal ** 2) # Orijinal sinyal gücü
    noise_power = np.mean(noise_signal ** 2) # Gürültü gücü

    if noise_power == 0:
        return np.inf # Gürültü sıfırsa SNR sonsuzdur
    return 10 * np.log10(signal_power / noise_power) # SNR değeri dB cinsinden hesaplama

# Ses dosyalarını yükle
wave_1, sr_1 = librosa.load(file_1, sr=None) # Birinci ses dosyasını yükle (örnekleme oranını koru)
wave_2, sr_2 = librosa.load(file_2, sr=None) # İkinci ses dosyasını yükle (örnekleme oranını koru)

# Her iki dosya için SNR hesapla
snr_1 = calculate_snr(wave_1, sr_1) # Birinci sinyalin SNR değeri
snr_2 = calculate_snr(wave_2, sr_2) # İkinci sinyalin SNR değeri

# Grafik çizimi
plt.figure(figsize=(8, 5)) # Grafik boyutu belirlenir
plt.bar([label_1, label_2], [snr_1, snr_2], color=['skyblue', 'salmon']) # SNR değerlerini bar grafikte gösterme
plt.title("Sinyal-Gürültü Oranı (SNR) Karşılaştırması") # Grafik başlığı
plt.ylabel("SNR (dB)") # Y ekseni etiketi
plt.grid(axis='y', linestyle='--', alpha=0.7) # Y ekseni için çizgili ızgara
plt.tight_layout() # Grafik elemanlarının sıkıştırılması
plt.show() # Grafiği ekranda gösterme
